# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import get_file
import numpy as np
import random
import sys
import io
import requests
import re

# %%
r = requests.get("https://data.heatonresearch.com/data/t81-558/text/treasure_island.txt")
raw_text = r.text
# print(raw_text[0:1000])

# %%
processed_text=raw_text.lower()
processed_text=re.sub(r'[^\x00-\x7f]',r'',processed_text);

# %%
print('corpus length',len(processed_text))
chars=sorted(list(set(processed_text)))
print('length of chars',len(chars))
char_indices=dict((c,i) for i ,c in enumerate(chars))
indices_chars=dict((i,c) for i ,c in enumerate(chars))
# Out:
# corpus length 397400
# length of chars 60

# %%
maxlen=40
step=3
sentences=[]
next_char=[]
for i in range(0,len(processed_text)-maxlen,step):
  sentences.append(processed_text[i:i+maxlen])
  next_char.append(processed_text[i+maxlen])
print('The Sequence is',len(sentences))
# Out:
# The Sequence is 132454

# %%
# sentences

# %%
# onehot encoding
print('Vectorization...')
x=np.zeros((len(sentences),maxlen,len(chars)),dtype=np.bool)
y=np.zeros((len(sentences),len(chars)),dtype=np.bool)
for i,sentence in enumerate(sentences):
  for t, char in enumerate(sentence):
    x[i,t,char_indices[char]]=1
  y[i,char_indices[next_char[i]]]=1
# Out:
# Vectorization...

# %%
x.shape
# Out:
# (132454, 40, 60)

# %%
y.shape
# Out:
# (132454, 60)

# %%
y[0:10]
# Out:
# array([[False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False,  True, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False,  True, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False,  True, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False,  True, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#          True, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False,  True, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False,  True, False,
#         False, False, False, False, False, False],
#        [False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False,  True, False, False, False, False]])

# %%
print('Build Model...')
model=Sequential()
model.add(LSTM(128,input_shape=(maxlen,len(chars))))
model.add(Dense(len(chars),activation='softmax'))
optimizer=RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy',optimizer=optimizer)
# Out:
# Build Model...

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 128)               96768
# _________________________________________________________________
# dense (Dense)                (None, 60)                7740
# =================================================================
# Total params: 104,508
# Trainable params: 104,508
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds,temperature=0.1):
  preds=np.asarray(preds).astype('float64')
  preds=np.log(preds)/temperature
  exp_preds=np.exp(preds)
  preds=exp_preds/np.sum(exp_preds)
  probas=np.random.multinomial(1,preds,1)
  return np.argmax(probas)

# %%
import random
import sys
def on_epoch_end(epoch, _):
  start_index = random.randint(0, len(processed_text) - maxlen - 1)
  for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('----- temperature:', temperature)

        generated = ''
        sentence = processed_text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)
        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = indices_chars[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

# %%
# Ignore useless W0819 warnings generated by TensorFlow 2.0.  Hopefully can remove this ignore in the future.
# See https://github.com/tensorflow/tensorflow/issues/31308
import logging, os
logging.disable(logging.WARNING)
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"

# Fit the model
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Epoch 1/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.5439
# ----- temperature: 0.2
# ----- Generating with seed: " is on a wrong tack, i
# do believe. and "
#  is on a wrong tack, i
# do believe. and the stare of the man stare of the story of the stare of the captain, and and the stare of the stare of the boat was a share of the boat was and the stare of the black of the boat was the stare and the strong of the stare of the boat was a ship of the stare of the stare of the stare of the stare of the stare of the stand of the stare of the stare of the stare of the stare of the stare of the stare
# ----- temperature: 0.5
# ----- Generating with seed: " is on a wrong tack, i
# do believe. and "
#  is on a wrong tack, i
# do believe. and a go the been stand of the out in the strong on the see stare, and the should on his hand, the strange but on to the shores. and his poss at the pire of a sterned of the first of the barrer work in the broke of the strough of the state, fell began to the stife, and the sure one of the bland of the stares of or father and the stare of my bore farshe come in the side of the boat dander who had seemi
# ----- temperature: 1.0
# ----- Generating with seed: " is on a wrong tack, i
# do believe. and "
#  is on a wrong tack, i
#
#
#
#
#
#
#
#
#
# ----- temperature: 1.2
# ----- Generating with seed: " is on a wrong tack, i
# do believe. and "
#  is on a wrong tack, i
#
#
#
#
#
#
#
#
#
#
# "jimp then-yomemning my onco was as or ay; by ten rat wents
# Epoch 2/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.4831
# ----- temperature: 0.2
# ----- Generating with seed: "oard,
# the sheet groaning in the blocks,"
# oard,
#
#
#
#
# "well, i said the squire. "well, so that i sea all in the shoulder and the man of the story with a good and so that i spoke of the story and shipped and short and comply and the shoulde
# ----- temperature: 0.5
# ----- Generating with seed: "oard,
# the sheet groaning in the blocks,"
# oard,
#
#
# "the swill had lay for his captain to go soon and ship, and so much and all the moat the worst of lade he sure him, and i spoke him, i said a countrantly and dark or in short and the arm o
# ----- temperature: 1.0
# ----- Generating with seed: "oard,
# the sheet groaning in the blocks,"
# oard,
#
#
#
#
#
#
#
#
#
#
# it could we was in, and pla
# ----- temperature: 1.2
# ----- Generating with seed: "oard,
# the sheet groaning in the blocks,"
# oard,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# theip a half-n affictect him, and pope so paderdations shalldwing, mest of once in
# Epoch 3/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.4422
# ----- temperature: 0.2
# ----- Generating with seed: "
# the captain's breakfast table--black d"
#
# the captain's breakfast table--black dog. the staring and the captain. "you're a state of the captain and we were a man to the parror and the strang of the story. the stare of the states and the stare of the captain and the stare of the stand of the stare. the stare of the captain and the stare of the stand of the captain should have sea a looked of the captain and the captain said the states when i had stated the stranging of the par
# ----- temperature: 0.5
# ----- Generating with seed: "
# the captain's breakfast table--black d"
#
# the captain's breakfast table--black don't don't fine a stand, and the rest, what we had stand not on the door and we were all and the others. the little were of the distribute, i could see in the strang of the captain, and when the same of my parron, and the man began to once man, and his comparron, as the cook of my hand of the state. a work. "these was the man we i could not sutch of the marron of the rudder and were it was a groan
# ----- temperature: 1.0
# ----- Generating with seed: "
# the captain's breakfast table--black d"
#
#
#
#
#
#
# --so along that sives on the man wold ben gunn you'll as that was ords of that, watviked,
# ----- temperature: 1.2
# ----- Generating with seed: "
# the captain's breakfast table--black d"
#
#
#
#
#
#
#
#
#
#
#
# for that possent,"
# Epoch 4/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.4132
# ----- temperature: 0.2
# ----- Generating with seed: "ds
# themselves began to grow more quiet,"
# ds
# themselves began to grow more quiet, and the captain. i seamen to the sea-ching the shorest the shores. the ship and the ship and the ship and the captain. "there we were a stopped of the ship and the captain and the storms. the captain was so the shorest the storms of the shot, and the shores was shoulder was soon and the captain was short. and the captain and the ship in the ship, and the ship and the ship and the shores. the shor
# ----- temperature: 0.5
# ----- Generating with seed: "ds
# themselves began to grow more quiet,"
# ds
#
#
#
#
# in the captain man was statration. but the storioss we was good through the storms. the
# ----- temperature: 1.0
# ----- Generating with seed: "ds
# themselves began to grow more quiet,"
# ds
#
#
#
#
# hudorstance, it was certainly the foir stood called you sendeion with treasure began to terrive, and as yor we went lung het the shoremance of the sandy all out out at the island propurtirg, very find which,
# ----- temperature: 1.2
# ----- Generating with seed: "ds
# themselves began to grow more quiet,"
# ds
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "nbeing the bulched along
# Epoch 5/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.3885
# ----- temperature: 0.2
# ----- Generating with seed: " "project
# gutenberg"), you agree to com"
#  "project
#
#
# "now, proves to the ship's long to the words of the strong of the stockade, and i was all the ship's the words of the strong to the ship's forment of
# ----- temperature: 0.5
# ----- Generating with seed: " "project
# gutenberg"), you agree to com"
#  "project
#
#
#
#
#
#
#
# by on the boats. he was ensoritions to be so
# ----- temperature: 1.0
# ----- Generating with seed: " "project
# gutenberg"), you agree to com"
#  "project
#
#
#
#
#
#
#
#
#
#
# geationake hand our cop', and the way and on. in the shames hel
# ----- temperature: 1.2
# ----- Generating with seed: " "project
# gutenberg"), you agree to com"
#  "project
#
#
#
#
#
#
#
#
#
#
#
#
#
# inscimhioseint. moreming sot once,      brierring, pittiing the light pi. of nailetow, willy cousi
# Epoch 6/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.3696
# ----- temperature: 0.2
# ----- Generating with seed: "eard the sound of loud voices from the c"
# eard the sound of loud voices from the chiess of the strange of the strong of the strange of the strange of the strong of the stockade of the strange of the states and man and heart of the book and the ship and the man of the strange of the strong of the current of the stockade of the strong of the strange of the strange of the ship and the chapterfarsion of the captain and the ship and the corner of the strong of the parrow of the stor
# ----- temperature: 0.5
# ----- Generating with seed: "eard the sound of loud voices from the c"
#
# and some sea the captain about the mainse, i see the sure reasure and with a man of the sound of other of the corner of man of the sonner of a sout of the current of the current of the boat was silver had been the man of the never ofter men were are it was a coup and ben gunn in
# ----- temperature: 1.0
# ----- Generating with seed: "eard the sound of loud voices from the c"
#
#
#
#
# take and whe
# ----- temperature: 1.2
# ----- Generating with seed: "eard the sound of loud voices from the c"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# but "youl the sedt
# Epoch 7/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.3531
# ----- temperature: 0.2
# ----- Generating with seed: "a hostage? are we a-going
# to waste a ho"
# a hostage? are we a-going
# to waste a how my fore of the south. the captain. "i was the boat was so the same of the silver began down the shore--and the captain. "i thought here and the spir and the south, and the same moment at the same side of the excet of the shore-was the same of the sand, and the captain. "i was a possible to the colort of the shore-was the same side of the same bear and rest to the fire of the boat, and the shore-
# ----- temperature: 0.5
# ----- Generating with seed: "a hostage? are we a-going
# to waste a ho"
# a hostage? are we a-going
# to waste a hottles of the stores of the color of among and in my mother of the sea a reasing and step as sail up the more to
# ----- temperature: 1.0
# ----- Generating with seed: "a hostage? are we a-going
# to waste a ho"
# a hostage? are we a-going
#
#
#
#
#
#
#
#
#
# about the xime to chare we make the water and accesmater and loopht, "sirmsil
# ----- temperature: 1.2
# ----- Generating with seed: "a hostage? are we a-going
# to waste a ho"
# a hostage? are we a-going
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# go him, a terroicle, bu
# Epoch 8/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.3426
# ----- temperature: 0.2
# ----- Generating with seed: "'s less a'ready, sir," said the man gray"
# 's less a'ready, sir," said the man gray of the trees. the same man to the stockade the same more the worst to the soon and the shore. the shore. and the shore. the same more to see the same meant of the stockade. the shore of the worst of the worst and the stockade of the same moment in the stockade, and the shore. i was the shore and the stockade and the sound of the thing to see the stockade and the stockade and the cooks of the shor
# ----- temperature: 0.5
# ----- Generating with seed: "'s less a'ready, sir," said the man gray"
# 's less a'ready, sir," said the man gray of the wind of the bear had the stockaded of head to see the captain the captain. "i'll closed to the man, and the stockade of the stockade of the worst the first and the ship behore the persor the ware the stiff of the worst; and the chossible with the shore. the shore. i'll be sure. i'll dong to the sea all that the pers, who had the ears of the sound of the stick of right and the most he was i
# ----- temperature: 1.0
# ----- Generating with seed: "'s less a'ready, sir," said the man gray"
#
#
#
#
#
# cert, we could aware we keet of severaf, peoples. if they part a one and core, into the one of a cood began to f
# ----- temperature: 1.2
# ----- Generating with seed: "'s less a'ready, sir," said the man gray"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# foreshor; of knewern givitidet
# Epoch 9/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.3323
# ----- temperature: 0.2
# ----- Generating with seed: ", up to the mid-leg in creeping vapor.
# "
# , up to the mid-leg in creeping vapor.
#
# "well, my more than i was all the treasure island and the shore of the stifling of the sounder is the stood to the captain as it was the shore and the shore and the ship's the shore to the sailor was any array to the shore and the shore and the shore and the shore. i was a man of the starror of the sounder was the shore and the shore and and as i am i was a shore of the shore as i was a soul hea
# ----- temperature: 0.5
# ----- Generating with seed: ", up to the mid-leg in creeping vapor.
# "
# , up to the mid-leg in creeping vapor.
#
# "deck, and then beach the trees last of the destribused the captain shoulder held my hand of the stifes and man the ship i show the bring to the soon of the sailorg the squire, and i could have the heart of us more so the sea the worst some took that was the man, as this man the sea swingraing to the story. i can't been manner to my hear of this and reserted and the bold, and well, had have the
# ----- temperature: 1.0
# ----- Generating with seed: ", up to the mid-leg in creeping vapor.
# "
# , up to the mid-leg in creeping vapor.
#
#
#
#
#
#
#
#
#
# warn hands spot to speaks, to our armh. weffery, more must, and then i says he. that
# ----- temperature: 1.2
# ----- Generating with seed: ", up to the mid-leg in creeping vapor.
# "
# , up to the mid-leg in creeping vapor.
#
#
#
#
#
#
#
#
#
# such a herlopusion,
# Epoch 10/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.3231
# ----- temperature: 0.2
# ----- Generating with seed: " the hill, and so on, so that in half a "
#  the hill, and so on, so that in half a land of the stockade of the stockade, and the color of the stick of the stockade and the stockade and the state the captain silver, and the boats," and the captain silver, and the words of the stick of the stockade, and the blandly, and the captain some to the barrel and the captain some to the stockade and the man was a strongiolar of the stick of the same stockade to the things of the state the
# ----- temperature: 0.5
# ----- Generating with seed: " the hill, and so on, so that in half a "
#
# while we found the distance took the anchorage. and the last and strange came better the stand, and we was in the main and a armis fortute, on the chart, and the fouled was to the east of the stood bear to seamen to the man was our other and dis
# ----- temperature: 1.0
# ----- Generating with seed: " the hill, and so on, so that in half a "
#
#
#
#
#
# enteroug a piw. grinnley all england water
# ----- temperature: 1.2
# ----- Generating with seed: " the hill, and so on, so that in half a "
#
#
#
#
#
#
#
#
#
#
#
#
#
# "we had aucharing to you wave betwectiul so dia i walk's m
# Epoch 11/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.3153
# ----- temperature: 0.2
# ----- Generating with seed: "eaking, groaning, and jumping like a man"
# eaking, groaning, and jumping like a man of the sears, and the shoulsed to the sea-chantering the book were a man we were now i was a man of the cooksier was so sears, and the shoulsed and the sea a ships of the story. and the cooksed of the stores and the shoulders, and the book were a soul the captain was so the sea-chantering, and the same of the sea and the shoulders and the shore. i was a shore, and the cooks, and the cookseas of t
# ----- temperature: 0.5
# ----- Generating with seed: "eaking, groaning, and jumping like a man"
#
#
# reaso
# ----- temperature: 1.0
# ----- Generating with seed: "eaking, groaning, and jumping like a man"
#
#
#
#
#
#
#
#
#
#
# ----- temperature: 1.2
# ----- Generating with seed: "eaking, groaning, and jumping like a man"
#
#
#
#
#
#
#
# soundly of a stream if poshing voited of seveked's very shall you
# Epoch 12/60
# 1035/1035 [==============================] - 6s 5ms/step - loss: 1.3083
# ----- temperature: 0.2
# ----- Generating with seed: "as red as a red ensign
# with his haste a"
# as red as a red ensign
# with his haste and the side, and a on the strong to the stores of the strictle of the strictle of the storitions the shoulder, and the captain sittle was a man of the strong of the strictly of the strong of the strong of the strictle of the sea and sprate at the same marring to the storitions of the same side of the same time of the strong of the strictly of the strong of the barrel as i are a clowl of the strong
# ----- temperature: 0.5
# ----- Generating with seed: "as red as a red ensign
# with his haste a"
# as red as a red ensign
#
#
# and a home the side, and then i was a man of a man of my moan. the barrow of men give a clate at the oak of feated to done much
# ----- temperature: 1.0
# ----- Generating with seed: "as red as a red ensign
# with his haste a"
# as red as a red ensign
#
#
#
#
#
#
#
#
#
#
#
#
# ----- temperature: 1.2
# ----- Generating with seed: "as red as a red ensign
# with his haste a"
# as red as a red ensign
#
#
#
#
#
#
#
#
#  lained. i treesf, and sometime ou
# Epoch 13/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2994
# ----- temperature: 0.2
# ----- Generating with seed: "as said.
#
# all at once there began the "
# as said.
#
#
#
# "well, now, and then i am sand the storyistake and shot t
# ----- temperature: 0.5
# ----- Generating with seed: "as said.
#
# all at once there began the "
# as said.
#
#
# roborting of an open most had least at the stargers, and you may lay to be some that with the rest and of the treat boats, as the worse, and there and at the way in the excut again.  he could seen the ship, and i say, and it was plunge my way with a creation of the shot was a barren and i was in gray where we were any any captain silver, but the distribute
# ----- temperature: 1.0
# ----- Generating with seed: "as said.
#
# all at once there began the "
# as said.
#
#
#
#
# coblegored. i had been one less my sb
#
#
#
# istirny was goatan, w
# ----- temperature: 1.2
# ----- Generating with seed: "as said.
#
# all at once there began the "
# as said.
#
#
#
#
#
#
# ladsed of recovine--
# Epoch 14/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2939
# ----- temperature: 0.2
# ----- Generating with seed: "ad turned the corner, and my home was ou"
# ad turned the corner, and my home was our more than the ship's the doctor beginning to the captain in the captain side and the captain spot and the stores and the captain spot, and then he was a man of the state to the captain side of the state to the captain side of the ships of the captain, i straight of the captain spot and the state that must book were and the ship was a man on the captain stopped to the state to the captain side of
# ----- temperature: 0.5
# ----- Generating with seed: "ad turned the corner, and my home was ou"
#
#
#
#
# was in the spore st
# ----- temperature: 1.0
# ----- Generating with seed: "ad turned the corner, and my home was ou"
#
#
#
#
#
#
#
#  lawkletoming him
# ----- temperature: 1.2
# ----- Generating with seed: "ad turned the corner, and my home was ou"
#
#
#
#
#
#
#
#
# ?"wande
# Epoch 15/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2882
# ----- temperature: 0.2
# ----- Generating with seed: "dad, and the cowardly son of a rum-punch"
# dad, and the cowardly son of a rum-punched the stockade, and the captain was the shoulder, and the shoulder, and the sea of the sea of the stores of the boat, and the sour should rather the stores and the sea all we could not the boat, and the shoulder, and the ship the captain we comes to the more that the the stick and the the same more that the thick the same more than the stores and the stick and the been that the way we come about
# ----- temperature: 0.5
# ----- Generating with seed: "dad, and the cowardly son of a rum-punch"
#
#
# brisk the account in the time to him all hand," said he, "incle a good below with the searver, and seen his shoulder, the same yound a side ship the had pretty before the doctor, i had don't d
# ----- temperature: 1.0
# ----- Generating with seed: "dad, and the cowardly son of a rum-punch"
#
#
#
#
#
# indorusawar of s
# ----- temperature: 1.2
# ----- Generating with seed: "dad, and the cowardly son of a rum-punch"
#
#
#
#
#
#
#
#
#
#
# worre pary to be sure,  't
#
#
#
#
#
#
# as we'velone to me time left money; m
# Epoch 16/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2840
# ----- temperature: 0.2
# ----- Generating with seed: "
# feet pointing in one direction, his ha"
#
# feet pointing in one direction, his hand of the stores of the book we had to the best the captain side of the corner of the shipmate of the shipmant of the book we come and spot book to the stores and the color of the stood but the man we had to his head of the book we were at the book well and the color of the best the sure of the book were and the door and the book we would have and the stand of the color of the corner of the color
# ----- temperature: 0.5
# ----- Generating with seed: "
# feet pointing in one direction, his ha"
#
#
#
#
# "why, you'll thought the door, and th
# ----- temperature: 1.0
# ----- Generating with seed: "
# feet pointing in one direction, his ha"
#
#
#
#
#
#
#
#
#
#
# ----- temperature: 1.2
# ----- Generating with seed: "
# feet pointing in one direction, his ha"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "comtaming the achee thatberihile, sir is good," at the quater in nightned s
# Epoch 17/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2777
# ----- temperature: 0.2
# ----- Generating with seed: "hand against the wall.
#
# "are you hurt?"
# hand against the wall.
#
#
#
# "and i could hear the sea of the boat was so the words in the corner of the stockade, and the blockhouse, and then the blockhouse. i was a staturions in the sea along the boat were a foundation of the state of the boat was so that we can taken the cabin of the sea and distributed of the stockade, and the boat was the sea along the stick and the blockhouse, and the boat was the man of the stoc
# ----- temperature: 0.5
# ----- Generating with seed: "hand against the wall.
#
# "are you hurt?"
# hand against the wall.
#
#
#
# i was statewiles was state the more as i began to the for to his spaning of his musket and found the book of my arm and sure a good color and the horse count been the one beside a man with a arrance and the time i was for that ground. the time in the first to the boat were i began to see a litt
# ----- temperature: 1.0
# ----- Generating with seed: "hand against the wall.
#
# "are you hurt?"
# hand against the wall.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# thas behan-was though o
# ----- temperature: 1.2
# ----- Generating with seed: "hand against the wall.
#
# "are you hurt?"
# hand against the wall.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "dayble thath the amus! clut, for's theis
# Epoch 18/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2750
# ----- temperature: 0.2
# ----- Generating with seed: "
#     health, that sends him back to rovi"
#
#
#
# the squire and the captain and a starring and the shoulder, and then he had so like the stockade, and then he had start of the deck of the starring and the strong to sea all was almost to have the three ben gunn't and the starring of the
# ----- temperature: 0.5
# ----- Generating with seed: "
#     health, that sends him back to rovi"
#
#
# redruth of his last of the cabin of the buccanger and there were flight, and the door and we were as some the reasure and we sailined with what the doctor was began to compry and the color of the pickantly and and sealen him the deck of for the sea-chest for a lear and no
# ----- temperature: 1.0
# ----- Generating with seed: "
#     health, that sends him back to rovi"
#
#
#
#
#
# and just insta
# ----- temperature: 1.2
# ----- Generating with seed: "
#     health, that sends him back to rovi"
#
#
#
#
#
#
#
#
# when to like he captrot
# Epoch 19/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2682
# ----- temperature: 0.2
# ----- Generating with seed: "the bad, i know. and i step aside--see h"
#
#
# "well, than i
# ----- temperature: 0.5
# ----- Generating with seed: "the bad, i know. and i step aside--see h"
#
#
#
#
# "whyn't a crution took the spidl of the chart of the worst the captain. "well, i to the side towards of the more silver, and shot on the bulks of the treasure was and the treasure here we took a great far to and fro, and there wer
# ----- temperature: 1.0
# ----- Generating with seed: "the bad, i know. and i step aside--see h"
#
#
#
#
#
#
#
#
#
#
#
#
# "buckle and tee kee
# ----- temperature: 1.2
# ----- Generating with seed: "the bad, i know. and i step aside--see h"
#
#
#
#
#
#
#
#
#
#
#
#
#
# i pamen."
# Epoch 20/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2638
# ----- temperature: 0.2
# ----- Generating with seed: "    an american gentleman
#        in acc"
#     an american gentleman
#
#
#
#
#
#
# "belia that the boat, and the captain sider of the stockade, and the man of the stick and the captain side the stockade, and the captain spoke of the captain. "i don't like a this the old better of the things and the black poss straight of th
# ----- temperature: 0.5
# ----- Generating with seed: "    an american gentleman
#        in acc"
#     an american gentleman
#
#
#
#
# the black poss said. i carage, and to his possible would the exposed at the sure in the ship behind my mind the creatif to that down comply into the bold island, and all was his color of the woods. if i was still, the thing, what i sailing the doctor lo
# ----- temperature: 1.0
# ----- Generating with seed: "    an american gentleman
#        in acc"
#     an american gentleman
#
#
#
#
#
# dance, dec
# ----- temperature: 1.2
# ----- Generating with seed: "    an american gentleman
#        in acc"
#     an american gentleman
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 21/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2593
# ----- temperature: 0.2
# ----- Generating with seed: "n his old shipmate and one, as i
# though"
# n his old shipmate and one, as i
# thought i don't done it was a side, and i am the sailor and the sure said to the sailor and the watch of the captain and the ship was a sound the captain side of the stars, and the whole stiff of any rate had seen a good stare to the sailor and the captain side of the man of the stockade, and the captain side to his shoulder and the ship was a sound of the started was a sound of his hand of the stockade
# ----- temperature: 0.5
# ----- Generating with seed: "n his old shipmate and one, as i
# though"
# n his old shipmate and one, as i
#
#
# grough the
# ----- temperature: 1.0
# ----- Generating with seed: "n his old shipmate and one, as i
# though"
# n his old shipmate and one, as i
#
#
#
#
#
#
#
#
# gresented his hand, now a more hidselyly was face l
# ----- temperature: 1.2
# ----- Generating with seed: "n his old shipmate and one, as i
# though"
# n his old shipmate and one, as i
#
#
#
#
#
#
#
#
# noimen  d
# Epoch 22/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2552
# ----- temperature: 0.2
# ----- Generating with seed: "and even between the clumps of
# nutmeg a"
# and even between the clumps of
# nutmeg and from the same moment the sure of the stick where i was a sure i was a side to the stick and the shores of the colore of the stick the stare to see the stick where i was a side and long to sea all the starrition, and the same time and the first the stick and round and spore a states of the sure shipmate for the stockade, and the stick and singing the stick and round the same time and the first t
# ----- temperature: 0.5
# ----- Generating with seed: "and even between the clumps of
# nutmeg a"
# and even between the clumps of
# nutmeg about the hands, and shoulder and the moment a sure shouting a sure and the stiff where shores in the pirates stand for a little trees with the man of the stick from the corner of the piget and the captain. "than he had leaving to the color and the seat of the powers. and the same moment the sore and drain a thind to the creation of the side of the last of stare by the starrition, whisely the this
# ----- temperature: 1.0
# ----- Generating with seed: "and even between the clumps of
# nutmeg a"
# and even between the clumps of
#
#
#
#
#
#
#
#
# componk raise plucked socly man. lout, and rill, that was every nost being in"--pige wordesable the man
# ----- temperature: 1.2
# ----- Generating with seed: "and even between the clumps of
# nutmeg a"
# and even between the clumps of
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mo
# Epoch 23/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2512
# ----- temperature: 0.2
# ----- Generating with seed: " fellow, probably he who had remained be"
#  fellow, probably he who had remained before the boy, and the captain. "now, i was a great sand of the stiff of the stiff of the corner of the stockade, and the corner of the stiff of the same to have a man of the state of the strange of the boy, and the ship and the same to the stockade, and the ship of the stiff of the corner of the pit if i seen the strong of the state of the work to the stockade, and the ship and the corner of the b
# ----- temperature: 0.5
# ----- Generating with seed: " fellow, probably he who had remained be"
#
# for the errembert and the chast; and the squire say, i could hear him had soon all the boat boat, and the sure that i could hear the great against the stifftly distribution of the gave of the light for the last of a hands and not a cruce, and the same more with my eyes of the gave of the powser of the sea any bright and her course,
# ----- temperature: 1.0
# ----- Generating with seed: " fellow, probably he who had remained be"
#
#
#
#
#
#
# up this one chrost that ligh
# ----- temperature: 1.2
# ----- Generating with seed: " fellow, probably he who had remained be"
#
#
#
#
#
#
# iggo as clondle hills twji!n not juste,     nox. indeapsion natival where himselfy, beging "here you-glancers sider. therewoup; in tturned to close, one point courses gufch, and riles to lad to know, and. this nive, i am rock, i h
# Epoch 24/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2487
# ----- temperature: 0.2
# ----- Generating with seed: "bout me, and so many poor
# dead bodies l"
# bout me, and so many poor
# dead bodies little the captain and the corner of the stranger and a ship was the sound of the first the stockade, and i should have and the boat and some time the ship's treasure was a steep. and then we came and ship he had the captain. "you are a companions to see him the stores. and then the black dog has been the start of the boat was a singing of the stockade, and the corner of the stockade, and he and th
# ----- temperature: 0.5
# ----- Generating with seed: "bout me, and so many poor
# dead bodies l"
# bout me, and so many poor
# dead bodies little that i could and a long and the deck the rest put it we came on distre in his side of the stern to see what i had a
# ----- temperature: 1.0
# ----- Generating with seed: "bout me, and so many poor
# dead bodies l"
# bout me, and so many poor
#
#
#
#
#
#
# indeuthing and what he
# ----- temperature: 1.2
# ----- Generating with seed: "bout me, and so many poor
# dead bodies l"
# bout me, and so many poor
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Epoch 25/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2463
# ----- temperature: 0.2
# ----- Generating with seed: "ulder of the spy-glass,
# and rising agai"
# ulder of the spy-glass,
# and rising again in the stranger was a steep with a man was so much as i was a stark with the start of the time was the captain. "there was the stranger strange with a stiff in the start of the start of the stranger was a stark with the work to the stifft and the pire to the start of the start of the start of the stockade, and the captain. "i have a good to see the stranger and the stiffy and the color of the st
# ----- temperature: 0.5
# ----- Generating with seed: "ulder of the spy-glass,
# and rising agai"
# ulder of the spy-glass,
# and rising again into black dog he had gone of a man, whistled my eyes hands of the pire to the treasure assided and fresh of his armal and was the noit of the boys, and the first work of the project gutenberg-to shipmate, and the captain, who was a haul the schooner was still and the stiffy in the doctor of the sure sail and the same time that as if it was the stray with a man who exciped the same tom on the ti
# ----- temperature: 1.0
# ----- Generating with seed: "ulder of the spy-glass,
# and rising agai"
# ulder of the spy-glass,
#
#
#
#
#
#
# seen the man wound the blackns--firty--and at to till frishm that's when, as he want
# ----- temperature: 1.2
# ----- Generating with seed: "ulder of the spy-glass,
# and rising agai"
# ulder of the spy-glass,
#
#
#
#
#
#
#
#
#
#
#
# strur euning. a confule, and looking arming, where here," said the captain. "and iexous
#  a-distances snja
# Epoch 26/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2404
# ----- temperature: 0.2
# ----- Generating with seed: " now and then telling me some little
# an"
#  now and then telling me some little
# and the doctor that the shoulder, and a man was a long the stockade and the shoulder was not the stockade, and the doctor of the stockade, and stares and the doctor of the stockade, and the black desiner the stockade and stares and the doctor was a contince was the boats and a man was the stockade and the direction of a sound of the stockade, and we were all the but that was for that was a thick and
# ----- temperature: 0.5
# ----- Generating with seed: " now and then telling me some little
# an"
#  now and then telling me some little
#
#
# "ahbage the brought of his head of the teere of the trees. he was to the door had starm the last walks, and then was that i was a thispates, i was a hands and the doctor captain smollett, and and miste that a pair of the color of his head, and a plumping hands, and soon the squire's boat were reasing the expect, and we can done was his shoulde
# ----- temperature: 1.0
# ----- Generating with seed: " now and then telling me some little
# an"
#  now and then telling me some little
#
#
#
#
#
#
# tas my cut an
# ----- temperature: 1.2
# ----- Generating with seed: " now and then telling me some little
# an"
#  now and then telling me some little
#
#
#
#
#
#
#
#
#
#
#
#
#
# lattect
# Epoch 27/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2353
# ----- temperature: 0.2
# ----- Generating with seed: "se many miles away, and was never near t"
#
#
#
#
# the squire of the starbor, and the first t
# ----- temperature: 0.5
# ----- Generating with seed: "se many miles away, and was never near t"
# se many miles away, and was never near the cold spout of his side and we was any long as the start of the captain. "you see, "i'm she had the color of the captain; "no sea-ceit, all of the six stare of a man was with what i seen him the smile and shot and seen the door and arost, and which would be the deck, and if i've seen provide to my bull of the story. if he came aboard to the captain, which to be sort of hands and swing the captai
# ----- temperature: 1.0
# ----- Generating with seed: "se many miles away, and was never near t"
#
#
#
#
#
#
#
#
# teermed trapped a s
# ----- temperature: 1.2
# ----- Generating with seed: "se many miles away, and was never near t"
#
#
#
#
#
#
#
#
#
#
# cried; aninearve. to there--
# Epoch 28/60
# 1035/1035 [==============================] - 6s 6ms/step - loss: 1.2356
# ----- temperature: 0.2
# ----- Generating with seed: "will any kind friend inform a poor blind"
# will any kind friend inform a poor blind of the story. i was a startly the particularly had a great beard and the story. i was a stick and the story. i was a start of the treachery and the corner, and the ship was a side of the story. i was a startly the captain. "they were all the story. i was a startle of the story. i saw the story. i was a good and the cold of the treat of the story. "you would have been the story. i was the story. i
# ----- temperature: 0.5
# ----- Generating with seed: "will any kind friend inform a poor blind"
#
#
# "the co
# ----- temperature: 1.0
# ----- Generating with seed: "will any kind friend inform a poor blind"
#
#
#
#
#
#
#
#
#
#
#
# the meanting of my mon. this seemed of that breate ne
# ----- temperature: 1.2
# ----- Generating with seed: "will any kind friend inform a poor blind"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# nlysion
# Epoch 29/60
# 1035/1035 [==============================] - 6s 5ms/step - loss: 1.2287
# ----- temperature: 0.2
# ----- Generating with seed: " a vicious horse, the
# sails filling, no"
#  a vicious horse, the
# sails filling, now and the shoulder side of the shot of the ship's shot of the same side of the story and the shoulder of the sea and company of the stores. i'll have all the worse of the sure of the sure of the sure of the stiffling. i was the sun and the sight of the sign of the ship's for the most to the sailor of the shores, and the shoulder shoulder sailor was the south, and then i was a seaman, and the shoul
# ----- temperature: 0.5
# ----- Generating with seed: " a vicious horse, the
# sails filling, no"
#  a vicious horse, the
#
#
# high was in the sun in the more to that with his sign, and the clean. and then i have the stiffling, i l
# ----- temperature: 1.0
# ----- Generating with seed: " a vicious horse, the
# sails filling, no"
#  a vicious horse, the
#
#
#
#
#
#
#
#
#
#
#
# ----- temperature: 1.2
# ----- Generating with seed: " a vicious horse, the
# sails filling, no"
#  a vicious horse, the
#
#
#
#
#
#
#
#
#
#
# whiling on al
# Epoch 30/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2253
# ----- temperature: 0.2
# ----- Generating with seed: ".
#
# there was a great, smooth swell upo"
# .
#
#
#
# "well, i could see the stockade, and the shoutage, and then the captain six things and the first the meantime was a hawkins, and the boy," said the captain. "that's a better
# ----- temperature: 0.5
# ----- Generating with seed: ".
#
# there was a great, smooth swell upo"
# .
#
#
#
#
# chart, and the sun in our back
# ----- temperature: 1.0
# ----- Generating with seed: ".
#
# there was a great, smooth swell upo"
# .
#
#
#
#
#
#
#
#
#
# "hure were to be disccaps
# ----- temperature: 1.2
# ----- Generating with seed: ".
#
# there was a great, smooth swell upo"
# .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   wo
# Epoch 31/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2216
# ----- temperature: 0.2
# ----- Generating with seed: "s.
#
# i think we were all pleased to be "
# s.
#
# i think we were all pleased to be the story, and then the strong to the stockade, and the ship were and the death of the story, and the ship was a steep to the captain. "they had the trees and the southern the story, and the chart and the shoulder and the story, and the captain and the corre, and when i seen a startaged to the sea-chist the story, and what i seen a startaging of the bottle of the powers. "i'll have been the story,
# ----- temperature: 0.5
# ----- Generating with seed: "s.
#
# i think we were all pleased to be "
# s.
#
#
# of the stockade, and in the world of the sea-chest at the intood of the stockade, you all hands to sea. it were before the thing the first the captain, onleeting, the down the state who had a good and the coast. there and the shoulder and th
# ----- temperature: 1.0
# ----- Generating with seed: "s.
#
# i think we were all pleased to be "
# s.
#
#
#
#
#
#
#
# ain
# ----- temperature: 1.2
# ----- Generating with seed: "s.
#
# i think we were all pleased to be "
# s.
#
#
#
#
#
#
#
#
# 2mede until and good is, i says o' neg provided no co  isfol of porch or two and could jim, to be sure caclod for fert shipposs. i could beaming
# Epoch 32/60
# 1035/1035 [==============================] - 6s 5ms/step - loss: 1.2222
# ----- temperature: 0.2
# ----- Generating with seed: "n was displeased at that; but my messmat"
# n was displeased at that; but my messmation and the story, and the stockade, and the story, and the word of the pit of the cut where the captain was the story, and then the story, and the same between the stores of the stores of the stores of the sea, and the captain was the captain would have been the captain was story and the story, and then the project gutenberg-tm anchor of the stores of the stores of the sure were a good stor. a su
# ----- temperature: 0.5
# ----- Generating with seed: "n was displeased at that; but my messmat"
#
#
#
#
# doctor, and then i
# ----- temperature: 1.0
# ----- Generating with seed: "n was displeased at that; but my messmat"
#
#
#
#
#
#
#
#
#
#
# the five out of a one
# ----- temperature: 1.2
# ----- Generating with seed: "n was displeased at that; but my messmat"
#
#
#
#
#
#
#
#
#
# to resuterf'in equally a grea on again, a b
# Epoch 33/60
# 1035/1035 [==============================] - 6s 5ms/step - loss: 1.2171
# ----- temperature: 0.2
# ----- Generating with seed: "llowance, sir, for all the gifts of prov"
# llowance, sir, for all the gifts of provide and the blockade, and then i said the captain side of the boats, and the captain sirves he had a steeped and the captain with a state of the boats, and the boat, and then leaded to me, and then i said the captain and a holder in the stockations with a steeped ben gunn of the boats, and a man of the boats, and the captain was fremtle, and then i was a start of the bottle of the boats, and the c
# ----- temperature: 0.5
# ----- Generating with seed: "llowance, sir, for all the gifts of prov"
#
#
#
#
# with the boats, and don't maken for the loose was and flowe of the most for a place, and with a startation all the time we come to cut the stockaten had the captain. now, they laid to get the parror and leaving to
# ----- temperature: 1.0
# ----- Generating with seed: "llowance, sir, for all the gifts of prov"
#
#
#
#
#
#
#
#
#
# sometime and toget the bad--all upon her head and dissma--wake
# ----- temperature: 1.2
# ----- Generating with seed: "llowance, sir, for all the gifts of prov"
#
#
#
#
#
#
#
#
# mrs. hhe's cretke     , near that delale?    gnevery came short. "now captimemen young one
# Epoch 34/60
# 1035/1035 [==============================] - 6s 5ms/step - loss: 1.2134
# ----- temperature: 0.2
# ----- Generating with seed: " go down the seaside of the spit to avoi"
#  go down the seaside of the spit to avoik the fore and the stockade, and the shoulder was the captain, who had still the stockade, and the shoulder shoulder shoulder should have the more of the word, and i was the stores, and the boat, where a start of the shipman of the stockade, and the more to the captain, and the stick were and the worst of the stores, and the black dog began to the stockade, and the captain was the best to the capt
# ----- temperature: 0.5
# ----- Generating with seed: " go down the seaside of the spit to avoi"
#  go down the seaside of the spit to avoie. and the door is as so moment at the stockade, and the father and for him the black supply and heart of the inn of a pitch of the other negror. "i behald a fine and the worst to project gutenberg theress of the work of a sure to the stores. "i'm the project gutenberg there work the stockade of the boat, and but it was that shot of the shores, and i was steep him a truce, and between the worse wo
# ----- temperature: 1.0
# ----- Generating with seed: " go down the seaside of the spit to avoi"
#
#
#
#
#
#
#
#
#
#
# ----- temperature: 1.2
# ----- Generating with seed: " go down the seaside of the spit to avoi"
#
#
#
#
#
#
# in hey misc! buick bones to give the brus
# Epoch 35/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2124
# ----- temperature: 0.2
# ----- Generating with seed: " sign of any
# wind, and the boats had to"
#  sign of any
#
#
# "well, when the same mark, and when i was a states, and the captain of the stockade, and when i was a states, and the captain. "that's a start of the spy-glass, and the sun of the stockade, and the captain. "when i had some to be prection of the stockade, and the squire, and the captain, and the squire's the island an
# ----- temperature: 0.5
# ----- Generating with seed: " sign of any
# wind, and the boats had to"
#  sign of any
#
#
#
#
#
#
# "well, is the rest and the sun of the stockade, and you'll give the stockade, and the same simas, and a signe of the project gutenberg-theress, i could hear the captain, and been belags of the de
# ----- temperature: 1.0
# ----- Generating with seed: " sign of any
# wind, and the boats had to"
#  sign of any
#
#
#
#
#
#
#
#
# "put the doctor land-ha
# ----- temperature: 1.2
# ----- Generating with seed: " sign of any
# wind, and the boats had to"
#  sign of any
#
#
#
#
#
#
#
#
#
# alsquire, while this still that stick a death, that he was butner--we're my sprot gal abouting times of a ma
# Epoch 36/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.2092
# ----- temperature: 0.2
# ----- Generating with seed: "ut her consort. five men only
# of those "
# ut her consort. five men only
#
#
#
#
# "w
# ----- temperature: 0.5
# ----- Generating with seed: "ut her consort. five men only
# of those "
# ut her consort. five men only
# of those and one of the stopped piped was on the project gutenberg flite of my elfeed of the doctor of a sand onless of the water and fell was all my ships, margens of the part of the and a cruin and now and several to was compleinure; the blockhouse, or me to one of the strange was now instantly, and the song out of the stern should have been the blood-unfouting and the strong of the treasure shoulder sha
# ----- temperature: 1.0
# ----- Generating with seed: "ut her consort. five men only
# of those "
# ut her consort. five men only
#
#
#
#
#
#
#
#         and once ships careal northeepress were had should a resswained out x
#
#
# trela
# ----- temperature: 1.2
# ----- Generating with seed: "ut her consort. five men only
# of those "
# ut her consort. five men only
# of those turng to softurn and good above a heart a nevj
#
#
#
#
#
#
#
#
# cortanty, no anchaded; he tave toward, sirb's best. is that's smul; for we were perhaps, listraw as so netrew eppleht pe
# Epoch 37/60
# 1035/1035 [==============================] - 6s 5ms/step - loss: 1.2034
# ----- temperature: 0.2
# ----- Generating with seed: "o that. where's all england's men now? i"
# o that. where's all england's men now? i had some the stores and the shout to the captain. "i sail at the sea and the corner to the stores of the corner to the stockade, and the boy, and the copy of a manner silver, and the corner of the stockade, and the sea and the companion last must be a good had stood the stockade, and the corner of the stockade, and the ship in the stockade, and the shiper was soon as i was sound of the porch with
# ----- temperature: 0.5
# ----- Generating with seed: "o that. where's all england's men now? i"
#
#
#
#
#
#
#
#
# the bottle was a sure jost, and singing the treasure had been the copy of the meantime, with the great gite barrel, without the thick was out the more still hands of the man were a sun i was a good str
# ----- temperature: 1.0
# ----- Generating with seed: "o that. where's all england's men now? i"
#
#
#
#
#
#
# them gove until this way it was tumbers the beside in each last, my hard of mling the eipel of the good dead, in hand round out h_ jqugser, we've lear the dooms, overhark to come to last th
# ----- temperature: 1.2
# ----- Generating with seed: "o that. where's all england's men now? i"
#
#
#
#
#
#
#
#
#
#
#
# archbragetion
# Epoch 38/60
# 1035/1035 [==============================] - 6s 5ms/step - loss: 1.2038
# ----- temperature: 0.2
# ----- Generating with seed: "oolery. the
# tide's made good enough by "
# oolery. the
#
#
#
# "and i was a stepper, and the stockade, and then i was a steady, and the stockade, and the captain sir," said the captain. "not compless and the door and the door and the s
# ----- temperature: 0.5
# ----- Generating with seed: "oolery. the
# tide's made good enough by "
# oolery. the
# tide's made good enough by the third of the color was with the three man of the looked perspration, and i was not been the crimages with a spirits i was a sure, and the captain, and so of the country with the trees computing to get the pickest to watence the stack in the strange of the state. the door and the door and began to see the cutlors, sir, and the boy. so to the thoughts. he was a long to fathout to the captain. "t
# ----- temperature: 1.0
# ----- Generating with seed: "oolery. the
# tide's made good enough by "
# oolery. the
#
#
#
#
#
#                           rare joined ently fellow, oncem, t
# ----- temperature: 1.2
# ----- Generating with seed: "oolery. the
# tide's made good enough by "
# oolery. the
#
#
#
#
# x
#
#
#
# Epoch 39/60
# 1035/1035 [==============================] - 6s 6ms/step - loss: 1.1968
# ----- temperature: 0.2
# ----- Generating with seed: "ronic works in accordance
# with this agr"
# ronic works in accordance
# with this agreement the first the stocka's that as the boat was a stick. he was still the first the same mostly the stocka's shot of the captain. "not a cruction of the stockade, and then i had a place of the stockade, and the boat was so that the boat was a start of the mains of the captain sides of the stockade, and then the current of the stockade, and then i had stilled him the captain. "not a fight in the
# ----- temperature: 0.5
# ----- Generating with seed: "ronic works in accordance
# with this agr"
# ronic works in accordance
# with this agreement to see the party camping the chest, i slope the cabin to and free and still rough the ship of states, where he word the same more than the stick. silver's bear the current, and he was the boat was speaking, and the mains in the same moment, the current of using and a bit of my father as a hawkins before i setted the stick. so help his time the boat to be curasion like a few still as he was
# ----- temperature: 1.0
# ----- Generating with seed: "ronic works in accordance
# with this agr"
# ronic works in accordance
#
#
#
#
#
#
#
#
#
# apply book as sometimesnefor intere g
# ----- temperature: 1.2
# ----- Generating with seed: "ronic works in accordance
# with this agr"
# ronic works in accordance
#
#
#
#
# enemnest, it was bs.fice his spurse norting mon he, neither as ever the current, "as you can i clapided. there biflee his change, disured we had unhomer, but going all at my matter's life. stev my faces yo
# Epoch 40/60
# 1035/1035 [==============================] - 6s 5ms/step - loss: 1.1977
# ----- temperature: 0.2
# ----- Generating with seed: "d a flag, you says."
#
# so he kept talki"
# d a flag, you says."
#
#
# ...
#
#
#
#
#
#
#
#
#
# for inthewain over, tuy, and the project gutenberg-tm sat
# Epoch 46/60
# 1035/1035 [==============================] - 6s 6ms/step - loss: 1.1851
# ----- temperature: 0.2
# ----- Generating with seed: " himself. but, mate, my heart is sore fo"
#
#
#
#
#
#
# "well, i was a start and the story. "i don't the stores of the story. i was any cross had been the captain situal me the story. i was so much and the same will had the stores of the sea and the story. "
# ----- temperature: 0.5
# ----- Generating with seed: " himself. but, mate, my heart is sore fo"
#
#
#
# we had stood, and then, ever distry with the story, and not a spot when i had as it wa
# ----- temperature: 1.0
# ----- Generating with seed: " himself. but, mate, my heart is sore fo"
#
#
#
#
#
#
#
#
#
# "i di
# ----- temperature: 1.2
# ----- Generating with seed: " himself. but, mate, my heart is sore fo"
#
#
#
#
#
#
# one
# Epoch 47/60
# 1035/1035 [==============================] - 6s 6ms/step - loss: 1.1834
# ----- temperature: 0.2
# ----- Generating with seed: "pose, for his chances of comfort in anot"
#
#
#
# was a start
# ----- temperature: 0.5
# ----- Generating with seed: "pose, for his chances of comfort in anot"
#
#
# and his hands and the place, and now,
# ----- temperature: 1.0
# ----- Generating with seed: "pose, for his chances of comfort in anot"
#
#
#
#
#
#
#
# cat'm; the drunwoly an
# ----- temperature: 1.2
# ----- Generating with seed: "pose, for his chances of comfort in anot"
#
#
#
#
#
#
#
#
# of appea
# Epoch 48/60
# 1035/1035 [==============================] - 6s 6ms/step - loss: 1.1822
# ----- temperature: 0.2
# ----- Generating with seed: " our true course, and away from our prop"
#  our true course, and away from our proporage of the captain. "it was a sure he was a stark when the captain silver had been the captain was the stifft and a sure ever was a stark when there was not a silent and the pire of the state of the sure of the sure of the man were flight and the sun had been to answer, and the blow of the sight i was a hands, and the blow of the boat, and the way in the stockade, and then i could do was a sure
# ----- temperature: 0.5
# ----- Generating with seed: " our true course, and away from our prop"
#
#
# "why, you'll, and here it were now, i could do the most perser of the esper books and we'll go up my father captain spot, and dong the pipen and good boarded the states shot. a piece of the destry of states of the bockesess and straight in the start of this and the round lay to the captain. "if i'll stumf but i am so of that a distre feet and the corner over he are together all was
# ----- temperature: 1.0
# ----- Generating with seed: " our true course, and away from our prop"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ----- temperature: 1.2
# ----- Generating with seed: " our true course, and away from our prop"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# evicing him a rail ssiffy. yo
# Epoch 49/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1776
# ----- temperature: 0.2
# ----- Generating with seed: "  [1. buried treasure--fiction. 2. pirat"
#
#
# gone of the wildor of the stores, and the captain. "we've a coupstage. and the captain silver was so long a little long john saying, a
# ----- temperature: 0.5
# ----- Generating with seed: "  [1. buried treasure--fiction. 2. pirat"
#
#
#
# bid, the brancy, while the
# ----- temperature: 1.0
# ----- Generating with seed: "  [1. buried treasure--fiction. 2. pirat"
#
#
#
#
#
#
# lay man, by which was a man must have been a way ihagetate the sea, that and tu
# ----- temperature: 1.2
# ----- Generating with seed: "  [1. buried treasure--fiction. 2. pirat"
#
#
#
# for kind, i told me rune me wohl-x
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# inn be; and uher
# Epoch 50/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1779
# ----- temperature: 0.2
# ----- Generating with seed: "idst of
# my terrors, until sleep at last"
# idst of
# my terrors, until sleep at last, and i was a second of the cooking and the shoulder and the shot of the bottle, and a sure of a manning to sea, and the shot of the stockade, and the shores of the woods as if it was a sound of the ship's shoulder and the shoulder of the stores of the parrunged on the stockade of the stores of the stockade, and i was soon to the shore. it was sound in the stockade, and we were a good seaman of th
# ----- temperature: 0.5
# ----- Generating with seed: "idst of
# my terrors, until sleep at last"
# idst of
#
#
#
# blood and tonling
# ----- temperature: 1.0
# ----- Generating with seed: "idst of
# my terrors, until sleep at last"
# idst of
#
#
#
# "by this giveways all tremsled both oking on that at the growpe of the inside up into all bable but it, and fowented now, there were continued him a crumber since the boat slose a bit, ighands, and turned in a manning against a paught--the bole a
# ----- temperature: 1.2
# ----- Generating with seed: "idst of
# my terrors, until sleep at last"
# idst of
#
#
#
#
#
#
#
#
#
#
# silver? whitence; we were
# Epoch 51/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1751
# ----- temperature: 0.2
# ----- Generating with seed: " could do was to dispatch a man to b----"
#
#
# "bellowed to the party to be sure the captain was the black noustle to the stockade. and then i have been the captain was
# ----- temperature: 0.5
# ----- Generating with seed: " could do was to dispatch a man to b----"
#
# for his shoulder was seemed place to see the most and the rest and the time he was still at the east, there we were all, a breather there we were a did with the instantly, and then i have been done, so that he was decess and storts and given by the moment of the stockade, and as your for a close and come of the others was a broaiursuad there was back and sh
# ----- temperature: 1.0
# ----- Generating with seed: " could do was to dispatch a man to b----"
#
#
#
#
#
# "that hands soon all he pance,  john he isfor. he looked of armileed. nowhoush, for a true in the spouf for what i had too. seemed sown essifurder," he fire me
# ----- temperature: 1.2
# ----- Generating with seed: " could do was to dispatch a man to b----"
#
#
#
#
#
#
#
#
#
#
#
#
#
# heibroked into his eye te
# Epoch 52/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1736
# ----- temperature: 0.2
# ----- Generating with seed: "voice broke out again--not this time sin"
#
#
# "the color of the spy-glas
# ----- temperature: 0.5
# ----- Generating with seed: "voice broke out again--not this time sin"
#
#
#
# "now, surpmium? for that as he was to looked him the color and the bough of the wood by the pirates of the long that a meart to go better must been the house; the south, and s
# ----- temperature: 1.0
# ----- Generating with seed: "voice broke out again--not this time sin"
#
#
#
#
#
#
#
#
#
# "lease, somet
# ----- temperature: 1.2
# ----- Generating with seed: "voice broke out again--not this time sin"
#
#
#
#
#
#
#
#
#
#
#
#   xx
# Epoch 53/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1720
# ----- temperature: 0.2
# ----- Generating with seed: ", as i warned him. now, mrs. hawkins,
# j"
# , as i warned him. now, mrs. hawkins,
# jim," said the captain. "well, i was the man the man who had the fore a state of the stockade, and then i was a startly and the man of the boats and the shores and the captain, "i was a startled beside the main and the foundation of the coracle, and the captain sitting the captain, i the captain, "that's a this conceal to be that board the boats and the mainsail of the main and the captain, "they t
# ----- temperature: 0.5
# ----- Generating with seed: ", as i warned him. now, mrs. hawkins,
# j"
# , as i warned him. now, mrs. hawkins,
#
#
#
# and i don't do you, and the other, and the man of the main of the sea close by the main, and it was a bottle of
# ----- temperature: 1.0
# ----- Generating with seed: ", as i warned him. now, mrs. hawkins,
# j"
# , as i warned him. now, mrs. hawkins,
#
#
#
#
#
#
#
#
#
# our marsun, and where it were strapy take top busilian of me cre
# ----- temperature: 1.2
# ----- Generating with seed: ", as i warned him. now, mrs. hawkins,
# j"
# , as i warned him. now, mrs. hawkins,
#
#
#
#
#
#
#
#
#
#
#
#
# breebsine. singing, a lungly, arose; there's guesin tr
# Epoch 54/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1643
# ----- temperature: 0.2
# ----- Generating with seed: "y! he was the
# blood-thirstiest buccanee"
# y! he was the
#
# and a sure shoulder was a low to the same men were and a side and the blood-hurror was the blocks, an
# ----- temperature: 0.5
# ----- Generating with seed: "y! he was the
# blood-thirstiest buccanee"
# y! he was the
#
#
# recent. but i was interron he striken to his set and the interest and a most on the trees, and at maning and the blood-hurring the man of the boy. i was possible with the best and a head of the stick and kinged the captain, and he was the captai
# ----- temperature: 1.0
# ----- Generating with seed: "y! he was the
# blood-thirstiest buccanee"
# y! he was the
#
#
# of he were's like roat officer be an rip took clean he heard clowded so some net. he aiking opened lition, he know the send of cap
# ----- temperature: 1.2
# ----- Generating with seed: "y! he was the
# blood-thirstiest buccanee"
# y! he was the
#
#
#
#
# first; i could there is," and the sorning. shin easy a bloadh. "you'v
# Epoch 55/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1688
# ----- temperature: 0.2
# ----- Generating with seed: "as
# helped across the stockade, after fo"
# as
# helped across the stockade, after forth that was a start of the bottle of the stiff of the staring and the start of the stiffling and the bottle from the staring from the stockade, and at the same moment the same mo;tand and the captain of the stockade before the captain, and the ship with a man who had a money. the sun i was so that all the start of the ship were all was the stifftlecking of the story. and the ship where he was so
# ----- temperature: 0.5
# ----- Generating with seed: "as
# helped across the stockade, after fo"
# as
#
#
#
# the starinion of let been that was the slope of the corner of the bore and the shook. but the schoundo is a bree i lay at last, i began to see the man, and so that all that all was so
# ----- temperature: 1.0
# ----- Generating with seed: "as
# helped across the stockade, after fo"
# as
#
#
#
#
#
#
#
#
#
#
# to have a rushmapes kingual of mi
# ----- temperature: 1.2
# ----- Generating with seed: "as
# helped across the stockade, after fo"
# as
#
#
#
#
#
#
#
#
#
#
#
#
# looked seach been trw came lift, and go
# Epoch 56/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1661
# ----- temperature: 0.2
# ----- Generating with seed: "   in london, i send this in double to b"
#
#
#
#
# "well, you're a little party with a coupsion of the story. which was the boats of the boomen was the boatswain shoulder, and the captain silver was so stood th
# ----- temperature: 0.5
# ----- Generating with seed: "   in london, i send this in double to b"
#
#
#
# had through the corsorarring had been now whomer to be whole come not the first he was how of her captain smollett had the captain silver was so that i have all, we we
# ----- temperature: 1.0
# ----- Generating with seed: "   in london, i send this in double to b"
#
#
#
# was now, mate roomed begun to it---i juck instantly, with a passed, and hardly blow through and your crippary like this, you cright with the foundation; ran here, mr. trelawney!
# ----- temperature: 1.2
# ----- Generating with seed: "   in london, i send this in double to b"
#
#   fuet; "silver was long to money, now a'way, not since a time x
#
#
#
#
#
#
#
# at the more that
# Epoch 57/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1638
# ----- temperature: 0.2
# ----- Generating with seed: "aces had been broken open in quest of th"
# aces had been broken open in quest of the pirates of the stockade, and a ship before the color of the treasure ship's pointer of the pirates of the color of the ship was so thing to the stockade, and a sure to the captain, and the colors, and the colors of the boats, and the blow of the color of the treasure shipmates, and the blockhouse, and the blockhouse, and the colors, and the boy," said he, "in the doctor to the things and the col
# ----- temperature: 0.5
# ----- Generating with seed: "aces had been broken open in quest of th"
#
# were but and a man again to the captain of the east of the stockade, "i saw it before he fell open more to have and left to see the fire roat of the man was we could see it
# ----- temperature: 1.0
# ----- Generating with seed: "aces had been broken open in quest of th"
#
#
#
# left led his laft
# ----- temperature: 1.2
# ----- Generating with seed: "aces had been broken open in quest of th"
#
#
#
#
#
#
#
#
#
#
#
# Epoch 58/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1599
# ----- temperature: 0.2
# ----- Generating with seed: "fore this butcher.
#
# wounded as he was,"
# fore this butcher.
#
# wounded as he was, and the foundation and the more than on the state to the stack, and the ship's person in the state had start of the mainsall that we could see the story. and the sure shipmate of the bottle of the stick and the ship's shoulder, and the stick and the sure shipmate of the stranger and the ship's shoulder that the stick and the shoulder, and the sea-chaster and the sailing that the sure shipmate of
# ----- temperature: 0.5
# ----- Generating with seed: "fore this butcher.
#
# wounded as he was,"
# fore this butcher.
#
# wounded as he was, groan the cap'n floor began to the more was for and recom, and that had been to me to my crutch, and shot of the supersid and seen the stick and a surprise shouting in the stockade; and when it was started me the blow of the birds of the worst of this waifted man was the boat, the cove of the fiverats of the terms of the stard, and go and the sure shipmate of the was she said, so my shored side t
# ----- temperature: 1.0
# ----- Generating with seed: "fore this butcher.
#
# wounded as he was,"
# fore this butcher.
#
#
#
#
# gavedled to see her--                                                                     nlits, and at arm hope, sin gaited about from the tee gent against the other shore, and
# ----- temperature: 1.2
# ----- Generating with seed: "fore this butcher.
#
# wounded as he was,"
# fore this butcher.
#
#
#
#
#
#
#
#
#
#
#
# weeper
# Epoch 59/60
# 1035/1035 [==============================] - 5s 5ms/step - loss: 1.1579
# ----- temperature: 0.2
# ----- Generating with seed: "to project gutenberg-tm electronic
# work"
# to project gutenberg-tm electronic
#
# men was a steady and the stard of the captain. "we've a man was a start of the mainsail of a man was a steady and start of the captain. "well, i don't like the bright that i had been straight of the captain. "we've have been the stard of the stranger was start of the
# ----- temperature: 0.5
# ----- Generating with seed: "to project gutenberg-tm electronic
# work"
# to project gutenberg-tm electronic
#
#
# in the
# ----- temperature: 1.0
# ----- Generating with seed: "to project gutenberg-tm electronic
# work"
# to project gutenberg-tm electronic
#
#
#
#
#
#
#
# saying that he
# ----- temperature: 1.2
# ----- Generating with seed: "to project gutenberg-tm electronic
# work"
# to project gutenberg-tm electronic
#
#
#
#
#
#
#
#
#
#
#
#
# ta digblaty. delay here, all aspeasarms, ah return on statted by one right in blave sail of put picked of viipive,
# Epoch 60/60
# 1035/1035 [==============================] - 6s 5ms/step - loss: 1.1608
# ----- temperature: 0.2
# ----- Generating with seed: " to seize upon the
# treasure, find and b"
#  to seize upon the
# treasure, find and been a sure to a man of the stockade, and then i could not stand and the boats, and the blockhouse, and then we've a bottle of the state of the booting had start at the state of the booting had been me a lights of the stockade, and the boy. i'll see the stockade, and then i had the boats, and when then then i could see the same moment the boats, and then he was states the black dog spoke out a comp
# ----- temperature: 0.5
# ----- Generating with seed: " to seize upon the
# treasure, find and b"
#  to seize upon the
#
# ----- temperature: 1.0
# ----- Generating with seed: " to seize upon the
# treasure, find and b"
#  to seize upon the
#
#
#
#
#
# slat, i'll to clean a mannaom. hismed bid. six by the worse of his part of his powle and a gallors
# ----- temperature: 1.2
# ----- Generating with seed: " to seize upon the
# treasure, find and b"
#  to seize upon the
#
#
# i
